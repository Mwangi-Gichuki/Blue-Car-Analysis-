# %%
# Importing of all libraries required for the analysis

import pandas as pd

import numpy as np 

import matplotlib.pyplot as plt

from datetime import datetime

# %%
# Loading the data from a csv file
# and displaying the top 10 items from the csv file

df = pd.read_csv('Autolib_dataset (2).csv')
df.head(10)
# Out:
#                               Address  Cars  Bluecar counter  Utilib counter  \
# 0                 2 Avenue de Suffren     0                0               0
# 1           145 Rue Raymond Losserand     6                6               0
# 2    2 Avenue John Fitzgerald Kennedy     3                3               0
# 3              51 Rue Eug̬ne Oudin̩     3                3               1
# 4  6 avenue de la Porte de Champerret     3                3               0
# 5                8 Boulevard Voltaire     0                0               0
# 6                      37 rue Leblanc     0                0               0
# 7         17 Rue des Luaps Prolong̩e     3                3               1
# 8               34 avenue Jean Moulin     1                1               0
# 9        41 boulevard de Rochechouart     6                6               0
#
#    Utilib 1.4 counter  Charge Slots Charging Status        City  \
# ...

# %%
# Understanding the data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Cars                 5000 non-null   int64
#  2   Bluecar counter      5000 non-null   int64
#  3   Utilib counter       5000 non-null   int64
#  4   Utilib 1.4 counter   5000 non-null   int64
#  5   Charge Slots         5000 non-null   int64
#  6   Charging Status      5000 non-null   object
#  7   City                 5000 non-null   object
#  8   Displayed comment    111 non-null    object
#  9   ID                   5000 non-null   object
#  10  Kind                 5000 non-null   object
#  11  Geo point            5000 non-null   object
#  12  Postal code          5000 non-null   int64
#  13  Public name          5000 non-null   object
#  14  Rental status        5000 non-null   object
# ...

# %%
# Checking for null values
# ---
# 
df.isnull().sum()
# Out:
# Address                   0
# Cars                      0
# Bluecar counter           0
# Utilib counter            0
# Utilib 1.4 counter        0
# Charge Slots              0
# Charging Status           0
# City                      0
# Displayed comment      4889
# ID                        0
# Kind                      0
# Geo point                 0
# Postal code               0
# Public name               0
# Rental status             0
# Scheduled at           4953
# Slots                     0
# Station type              0
# Status                    0
# Subscription status       0
# year                      0
# month                     0
# day                       0
# hour                      0
# minute                    0
# dtype: int64

# %%
# The 'Displayed comment' and 'Scheduled at' columns were observed to have a lot of null values and are of no 
# significance to the analysis and therefore okay to be dropped

df.drop(['Displayed comment','Scheduled at'], axis = 1)
# Out:
#                                  Address  Cars  Bluecar counter  \
# 0                    2 Avenue de Suffren     0                0
# 1              145 Rue Raymond Losserand     6                6
# 2       2 Avenue John Fitzgerald Kennedy     3                3
# 3                 51 Rue Eug̬ne Oudin̩     3                3
# 4     6 avenue de la Porte de Champerret     3                3
# ...                                  ...   ...              ...
# 4995                 8 avenue M̩nelotte     2                2
# 4996                   37 rue de Dantzig     4                4
# 4997                      142 rue du Bac     1                1
# 4998         2 avenue du Val de Fontenay     2                2
# 4999                 5 Rue Henry Brisson     4                4
#
#       Utilib counter  Utilib 1.4 counter  Charge Slots Charging Status  \
# 0                  0                   0             0     nonexistent
# ...

# %%
df.apply(lambda x:datetime.strptime("{0} {1} {2}".format(x['year'],x['month'], x['day']), "%YYYY %MM %dd "),axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-c093395f4725> in <module>
# ----> 1 df.apply(lambda x:datetime.strptime("{0} {1} {2}".format(x['year'],x['month'], x['day']), "%YYYY %MM %dd "),axis=1)
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ...
